# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
hh = pd.read_csv('/Users/laurahughes/GitHub/Ethiopia/Data/ETH_201506_cHealth.csv')

hh.stunted

# %%
pal = dict(male="#6495ED", female="#F08080")

sns.lmplot(x="ageMonths", y="stunted", data=hh, 
           hue = 'year', y_jitter=.02,
           palette = pal,
            logistic = True)

# %%
sns.jointplot?
